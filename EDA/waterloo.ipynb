# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('D:\CASApre\CUSP2024\EDA\Data\Waterloo_CE2.csv')

# %%
df.head(5)
# Out:
#               time  PM2.5 Particulate (ug/m3)  PM10 Particulate (ug/m3)  \
# 0  2023/10/27 0:00                        7.6                      11.8
# 1  2023/10/27 1:00                        7.2                      11.3
# 2  2023/10/27 2:00                        7.0                      11.2
# 3  2023/10/27 3:00                        6.7                      11.1
# 4  2023/10/27 4:00                        6.4                      10.9
#
#    Ozone (ug/m3)  Nitrogen Dioxide (ug/m3)
# 0            NaN                      43.5
# 1            NaN                      44.8
# 2            NaN                      38.6
# 3            NaN                      38.5
# 4            NaN                      38.9

# %%
df['time'] = pd.to_datetime(df['time'])

# %%
df.set_index('time', inplace=True)

plt.figure(figsize=(10, 6))
plt.plot(df.index, df['PM2.5 Particulate (ug/m3)'], label='PM2.5')
plt.plot(df.index, df['PM10 Particulate (ug/m3)'], label='PM10')
plt.plot(df.index, df['Ozone (ug/m3)'], label='O3')
plt.plot(df.index, df['Nitrogen Dioxide (ug/m3)'], label='NO2')
plt.xlabel('Time')
plt.ylabel('Concentration')
plt.title('Concentration Over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
df.set_index('time', inplace=True)

plt.figure(figsize=(10, 6))
plt.plot(df.index, df['PM2.5 Particulate (ug/m3)'], label='PM2.5')
plt.plot(df.index, df['PM10 Particulate (ug/m3)'], label='PM10')
plt.plot(df.index, df['Ozone (ug/m3)'], label='O3')
plt.plot(df.index, df['Nitrogen Dioxide (ug/m3)'], label='NO2')
plt.xlabel('Time')
plt.ylabel('Concentration')
plt.title('Concentration Over Time')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19084\184361533.py in ?()
# ----> 1 df.set_index('time', inplace=True)
#       2
#       3 plt.figure(figsize=(10, 6))
#       4 #plt.plot(df.index, df['PM2.5 Particulate (ug/m3)'], label='PM2.5')
#
# c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5855                     if not found:
#    5856                         missing.append(col)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#    5862             frame = self
#
# KeyError: "None of ['time'] are in the columns"
